# %%
from sklearn.metrics import jaccard_score
import pandas as pd
import numpy as np
import os

folder = os.path.join("/", "RanD", "CREMEv2_Result", "Reproducibility_Measurement", "Original", "accounting")

data_dir = ["accounting", "syslog", "traffic"]

date_file = ["20230310", 
         "20230420", 
         "20230424", 
         "20230426", 
         "20230502"]

for date in date_file:
    print("Information of dataset on ", date)
    df = pd.read_csv(os.path.join(folder, "label_accounting_"+date+".csv" ))
    df.info()
# Out:
# Information of dataset on  20230310
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4583180 entries, 0 to 4583179
# Data columns (total 46 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   TIMESTAMP        float64
#  1   RDDSK            int64
#  2   WRDSK            int64
#  3   WCANCL           int64
#  4   DSK              int64
#  5   MINFLT           float64
#  6   MAJFLT           int64
#  7   VSTEXT           int64
#  8   VSIZE            float64
#  9   RSIZE            float64
#  10  VGROW            float64
#  11  RGROW            float64
#  12  MEM              int64
#  13  TRUN             int64
#  14  TSLPI            int64
#  15  TSLPU            int64
#  16  NICE             int64
#  17  PRI              int64
#  18  RTPR             int64
#  19  CPUNR            int64
#  20  CPU              int64
#  21  Label            int64
#  22  Label_lifecycle  int64
#  23  POLI_-           int64
#  24  POLI_fifo        int64
# ...
