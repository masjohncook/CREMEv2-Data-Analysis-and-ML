# %%
"""
This is a simple application for sentence embeddings: clustering

Sentences are mapped to sentence embeddings and then agglomerative clustering with a threshold is applied.
"""
from sklearn.neighbors import NearestCentroid
import numpy as np
import pandas as pd
import os
import re
from sentence_transformers import SentenceTransformer, util
import time
from sklearn.cluster import AgglomerativeClustering

embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Corpus with example sentences
# corpus = ['A man is eating food.',
#           'A man is eating a piece of bread.',
#           'A man is eating pasta.',
#           'The girl is carrying a baby.',
#           'The baby is carried by the woman',
#           'A man is riding a horse.',
#           'A man is riding a white horse on an enclosed ground.',
#           'A monkey is playing drums.',
#           'Someone in a gorilla costume is playing a set of drums.',
#           'A cheetah is running behind its prey.',
#           'A cheetah chases prey on across a field.'
#           ]
root_folder = '../CREME_dataset/modify'
r_state = 42

df = pd.read_csv(os.path.join(root_folder, "original_relabel_syslog.csv"))
# df = df.sample(n=1000, random_state=r_state)
content = list(df['Content'])
print(len(content))
for i in range(len(content)):
    content[i] = re.sub('(?:[0-9]{1,3}\.){3}[0-9]{1,3}', '<*>', content[i])
    content[i] = re.sub('port [0-9]{1,5}', 'port <*>', content[i])
corpus = list(set(content))
print(len(corpus))

#Two parameters to tune:
#min_cluster_size: Only consider cluster that have at least 25 elements
#threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
corpus_embeddings = embedder.encode(corpus)
print(corpus_embeddings.shape)


# Normalize the embeddings to unit length
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# Perform kmean clustering
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=0.5) #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

print(len(clustered_sentences))

for i, cluster in clustered_sentences.items():
    print("Cluster ", i+1)
    print(len(cluster))
    for sentence_id in cluster[0:3]:
        print("\t", sentence_id)
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", sentence_id)
    print("")

clustering_model2 = AgglomerativeClustering(n_clusters=None, distance_threshold=3) #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model2.fit(corpus_embeddings)
cluster_assignment2 = clustering_model2.labels_
print(clustering_model2.n_clusters_)
# Out:
# 235952
# 130
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# torch.Size([130, 384])
# 65
# Cluster  51
# 4
# 	 "GET /chat/read_log.php HTTP/1.1" 404 505 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "GET /chat/read_log.php HTTP/1.1" 404 504 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "GET /chat/read_log.php HTTP/1.1" 404 503 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 ...
# 	 "GET /chat/read_log.php HTTP/1.1" 404 504 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "GET /chat/read_log.php HTTP/1.1" 404 503 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "GET /chat/read_log.php HTTP/1.1" 404 468 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
#
# Cluster  33
# 1
# 	 (root) CMD (   cd / && run-parts --report /etc/cron.hourly)
# 	 ...
# 	 (root) CMD (   cd / && run-parts --report /etc/cron.hourly)
#
# Cluster  37
# 1
# 	 pam_unix(samba:session): session closed for user nobody
# 	 ...
# 	 pam_unix(samba:session): session closed for user nobody
#
# Cluster  29
# 14
# 	 statistics: max connection count 1 for (submission:<*>) at Mar  6 19:15:51
# 	 statistics: max connection count 2 for (submission:<*>) at Mar  6 19:08:44
# 	 statistics: max connection count 1 for (submission:<*>) at Mar  6 19:05:50
# 	 ...
# 	 statistics: max connection count 2 for (submission:<*>) at Mar  6 18:38:06
# 	 statistics: max connection count 1 for (submission:<*>) at Mar  6 18:45:09
# 	 statistics: max connection count 1 for (submission:<*>) at Mar  6 19:15:50
#
# Cluster  40
# 1
# 	 enp0s3: DHCPv6 address fd36:97d8:258c::3c0/128 timeout preferred 43200 valid 43200
# 	 ...
# 	 enp0s3: DHCPv6 address fd36:97d8:258c::3c0/128 timeout preferred 43200 valid 43200
#
# Cluster  1
# 2
# 	 pam_unix(cron:session): session closed for user root
# 	 pam_unix(cron:session): session opened for user root by (uid=0)
# 	 ...
# 	 pam_unix(cron:session): session closed for user root
# 	 pam_unix(cron:session): session opened for user root by (uid=0)
#
# Cluster  36
# 1
# 	 doit: getnameinfo: Success
# 	 ...
# 	 doit: getnameinfo: Success
#
# Cluster  11
# 15
# 	 statistics: max connection rate 30/60s for (submission:<*>) at Mar  6 18:36:08
# 	 statistics: max connection rate 31/60s for (submission:<*>) at Mar  6 18:49:29
# 	 statistics: max connection rate 31/60s for (submission:<*>) at Mar  6 18:48:30
# 	 ...
# 	 statistics: max connection rate 1303/60s for (submission:<*>) at Mar  6 18:40:56
# 	 statistics: max connection rate 30/60s for (submission:<*>) at Mar  6 19:06:48
# 	 statistics: max connection rate 30/60s for (submission:<*>) at Mar  6 18:17:48
#
# Cluster  21
# 2
# 	 localhost (<*>[<*>]) - FTP session opened.
# 	 localhost (<*>[<*>]) - FTP session closed.
# 	 ...
# 	 localhost (<*>[<*>]) - FTP session opened.
# 	 localhost (<*>[<*>]) - FTP session closed.
#
# Cluster  9
# 2
# 	 Protocol major versions differ for <*>: SSH-2.0-OpenSSH_6.6.1p1 Ubuntu-2ubuntu2.13 vs. SSH-1.5-NmapNSE_1.0
# 	 Protocol major versions differ for <*>: SSH-2.0-OpenSSH_6.6.1p1 Ubuntu-2ubuntu2.13 vs. SSH-1.5-Nmap-SSH1-Hostkey
# 	 ...
# 	 Protocol major versions differ for <*>: SSH-2.0-OpenSSH_6.6.1p1 Ubuntu-2ubuntu2.13 vs. SSH-1.5-NmapNSE_1.0
# 	 Protocol major versions differ for <*>: SSH-2.0-OpenSSH_6.6.1p1 Ubuntu-2ubuntu2.13 vs. SSH-1.5-Nmap-SSH1-Hostkey
#
# Cluster  52
# 1
# 	 "GET /robots.txt HTTP/1.1" 404 466 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /robots.txt HTTP/1.1" 404 466 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  23
# 5
# 	 "GET /nmaplowercheck1678097419 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET /nmaplowercheck1678100924 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET /nmaplowercheck1678092898 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /nmaplowercheck1678092898 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET /nmaplowercheck1678099083 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET /nmaplowercheck1678095344 HTTP/1.1" 404 480 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  2
# 7
# 	 statistics: max cache size 4 at Mar  6 19:07:16
# 	 statistics: max cache size 4 at Mar  6 16:53:30
# 	 statistics: max cache size 4 at Mar  6 18:36:35
# 	 ...
# 	 statistics: max cache size 4 at Mar  6 18:08:51
# 	 statistics: max cache size 1 at Mar  6 19:05:50
# 	 statistics: max cache size 4 at Mar  6 17:34:16
#
# Cluster  28
# 2
# 	 statistics: max connection count 4 for (smtp:<*>) at Mar  6 18:10:54
# 	 statistics: max connection count 3 for (smtp:<*>) at Mar  6 17:36:17
# 	 ...
# 	 statistics: max connection count 4 for (smtp:<*>) at Mar  6 18:10:54
# 	 statistics: max connection count 3 for (smtp:<*>) at Mar  6 17:36:17
#
# Cluster  59
# 2
# 	 statistics: max connection rate 375/60s for (smtp:<*>) at Mar  6 16:55:34
# 	 statistics: max connection rate 1182/60s for (smtp:<*>) at Mar  6 19:11:36
# 	 ...
# 	 statistics: max connection rate 375/60s for (smtp:<*>) at Mar  6 16:55:34
# 	 statistics: max connection rate 1182/60s for (smtp:<*>) at Mar  6 19:11:36
#
# Cluster  4
# 3
# 	 localhost (<*>[<*>]) - USER non-vulnerable-machine-1: Login successful.
# 	 localhost (<*>[<*>]) - USER non-vulnerable-machine-2: Login successful.
# 	 localhost (<*>[<*>]) - USER vulnerable-machine: Login successful.
# 	 ...
# 	 localhost (<*>[<*>]) - USER non-vulnerable-machine-1: Login successful.
# 	 localhost (<*>[<*>]) - USER non-vulnerable-machine-2: Login successful.
# 	 localhost (<*>[<*>]) - USER vulnerable-machine: Login successful.
#
# Cluster  60
# 1
# 	 connect from <*> (<*>)
# 	 ...
# 	 connect from <*> (<*>)
#
# Cluster  14
# 3
# 	 "GET /contact.html HTTP/1.1" 200 7144 "-" "python-requests/2.16.0"
# 	 "GET /index.html HTTP/1.1" 200 4445 "-" "python-requests/2.16.0"
# 	 "GET /about.html HTTP/1.1" 200 3527 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /contact.html HTTP/1.1" 200 7144 "-" "python-requests/2.16.0"
# 	 "GET /index.html HTTP/1.1" 200 4445 "-" "python-requests/2.16.0"
# 	 "GET /about.html HTTP/1.1" 200 3527 "-" "python-requests/2.16.0"
#
# Cluster  57
# 1
# 	 "GET /HNAP1 HTTP/1.1" 404 461 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /HNAP1 HTTP/1.1" 404 461 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  3
# 4
# 	 "WKSZ / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "NIIZ / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "FHWL / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "NIIZ / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "FHWL / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "KDUN / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  56
# 1
# 	 "GET /pricing.html HTTP/1.1" 200 3161 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /pricing.html HTTP/1.1" 200 3161 "-" "python-requests/2.16.0"
#
# Cluster  54
# 1
# 	 main Q:Reg: worker thread c32570 terminated, now 1 active worker threads [v8.2208.0 try https://www.rsyslog.com/e/2439 ]
# 	 ...
# 	 main Q:Reg: worker thread c32570 terminated, now 1 active worker threads [v8.2208.0 try https://www.rsyslog.com/e/2439 ]
#
# Cluster  44
# 1
# 	 pam_nologin(login:auth): cannot determine username
# 	 ...
# 	 pam_nologin(login:auth): cannot determine username
#
# Cluster  58
# 1
# 	 org.codehaus.plexus.redback.struts2.interceptor.ForceAdminUserInterceptor  - Admin user found. No need to configure admin user.
# 	 ...
# 	 org.codehaus.plexus.redback.struts2.interceptor.ForceAdminUserInterceptor  - Admin user found. No need to configure admin user.
#
# Cluster  45
# 1
# 	 "POST /sdk HTTP/1.1" 404 459 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "POST /sdk HTTP/1.1" 404 459 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  12
# 2
# 	 Accepted password for root from <*> port <*> ssh2
# 	 Failed password for root from <*> port <*> ssh2
# 	 ...
# 	 Accepted password for root from <*> port <*> ssh2
# 	 Failed password for root from <*> port <*> ssh2
#
# Cluster  49
# 2
# 	 "GET / HTTP/1.1" 200 34971 "-" "-"
# 	 "GET / HTTP/1.0" 200 34990 "-" "-"
# 	 ...
# 	 "GET / HTTP/1.1" 200 34971 "-" "-"
# 	 "GET / HTTP/1.0" 200 34990 "-" "-"
#
# Cluster  39
# 1
# 	 fatal: no hostkey alg [preauth]
# 	 ...
# 	 fatal: no hostkey alg [preauth]
#
# Cluster  7
# 2
# 	 SSL_accept error from unknown[<*>]: Connection reset by peer
# 	 SSL_accept error from unknown[<*>]: lost connection
# 	 ...
# 	 SSL_accept error from unknown[<*>]: Connection reset by peer
# 	 SSL_accept error from unknown[<*>]: lost connection
#
# Cluster  35
# 1
# 	 doit: getaddrinfo: Name or service not known
# 	 ...
# 	 doit: getaddrinfo: Name or service not known
#
# Cluster  15
# 2
# 	 "PROPFIND / HTTP/1.1" 405 533 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "POST / HTTP/1.1" 200 34990 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "PROPFIND / HTTP/1.1" 405 533 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "POST / HTTP/1.1" 200 34990 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  24
# 2
# 	 SSL_accept error from unknown[<*>]: 0
# 	 SSL_accept error from unknown[<*>]: -1
# 	 ...
# 	 SSL_accept error from unknown[<*>]: 0
# 	 SSL_accept error from unknown[<*>]: -1
#
# Cluster  50
# 2
# 	 "OPTIONS / HTTP/1.1" 200 180 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"]
# 	 "OPTIONS / HTTP/1.1" 200 180 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "OPTIONS / HTTP/1.1" 200 180 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"]
# 	 "OPTIONS / HTTP/1.1" 200 180 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  61
# 1
# 	 pam_unix(sshd:session): session opened for user root by (uid=0)
# 	 ...
# 	 pam_unix(sshd:session): session opened for user root by (uid=0)
#
# Cluster  19
# 2
# 	 "GET /blog.html HTTP/1.1" 200 4170 "-" "python-requests/2.16.0"
# 	 "GET /blog_details.html HTTP/1.1" 200 4939 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /blog.html HTTP/1.1" 200 4170 "-" "python-requests/2.16.0"
# 	 "GET /blog_details.html HTTP/1.1" 200 4939 "-" "python-requests/2.16.0"
#
# Cluster  30
# 1
# 	 [20033.027511] IPv6: enp0s3: IPv6 duplicate address fd36:97d8:258c::3c0 used by 08:00:27:4a:62:8a detected!
# 	 ...
# 	 [20033.027511] IPv6: enp0s3: IPv6 duplicate address fd36:97d8:258c::3c0 used by 08:00:27:4a:62:8a detected!
#
# Cluster  55
# 1
# 	 <*>: closeFlag: Stage 1
# 	 ...
# 	 <*>: closeFlag: Stage 1
#
# Cluster  34
# 1
# 	 pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=<*>  user=root
# 	 ...
# 	 pam_unix(sshd:auth): authentication failure; logname= uid=0 euid=0 tty=ssh ruser= rhost=<*>  user=root
#
# Cluster  53
# 1
# 	 "GET /courses.html HTTP/1.1" 200 3242 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /courses.html HTTP/1.1" 200 3242 "-" "python-requests/2.16.0"
#
# Cluster  10
# 2
# 	 warning: non-SMTP command from unknown[<*>]: )ysm:????????
# 	 warning: non-SMTP command from unknown[<*>]: yg:????
# 	 ...
# 	 warning: non-SMTP command from unknown[<*>]: )ysm:????????
# 	 warning: non-SMTP command from unknown[<*>]: yg:????
#
# Cluster  27
# 1
# 	 connect from unknown[<*>]
# 	 ...
# 	 connect from unknown[<*>]
#
# Cluster  62
# 1
# 	 "GET /.git/HEAD HTTP/1.1" 404 465 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /.git/HEAD HTTP/1.1" 404 465 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  46
# 1
# 	 lost connection after STARTTLS from unknown[<*>]
# 	 ...
# 	 lost connection after STARTTLS from unknown[<*>]
#
# Cluster  64
# 1
# 	 warning: unknown[<*>]: SASL NTLM authentication failed: Invalid authentication mechanism
# 	 ...
# 	 warning: unknown[<*>]: SASL NTLM authentication failed: Invalid authentication mechanism
#
# Cluster  5
# 2
# 	 lost connection after CONNECT from unknown[<*>]
# 	 lost connection after UNKNOWN from unknown[<*>]
# 	 ...
# 	 lost connection after CONNECT from unknown[<*>]
# 	 lost connection after UNKNOWN from unknown[<*>]
#
# Cluster  42
# 1
# 	 disconnect from unknown[<*>]
# 	 ...
# 	 disconnect from unknown[<*>]
#
# Cluster  65
# 1
# 	 Did not receive identification string from <*>
# 	 ...
# 	 Did not receive identification string from <*>
#
# Cluster  8
# 2
# 	 [  770.884484] TCP: TCP: Possible SYN flooding on port <*>. Sending cookies.  Check SNMP counters.
# 	 [ 8705.374032] TCP: TCP: Possible SYN flooding on port <*>. Sending cookies.  Check SNMP counters.
# 	 ...
# 	 [  770.884484] TCP: TCP: Possible SYN flooding on port <*>. Sending cookies.  Check SNMP counters.
# 	 [ 8705.374032] TCP: TCP: Possible SYN flooding on port <*>. Sending cookies.  Check SNMP counters.
#
# Cluster  41
# 1
# 	 pam_unix(sshd:session): session closed for user root
# 	 ...
# 	 pam_unix(sshd:session): session closed for user root
#
# Cluster  17
# 1
# 	 "GET /assets/img/favicon.ico HTTP/1.1" 200 1413 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /assets/img/favicon.ico HTTP/1.1" 200 1413 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  26
# 1
# 	 "GET /gallery.html HTTP/1.1" 200 2942 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /gallery.html HTTP/1.1" 200 2942 "-" "python-requests/2.16.0"
#
# Cluster  20
# 1
# 	 localhost (<*>[<*>]) - USER ftp: no such user found from <*> [<*>] to <*>:21
# 	 ...
# 	 localhost (<*>[<*>]) - USER ftp: no such user found from <*> [<*>] to <*>:21
#
# Cluster  63
# 1
# 	 Received disconnect from <*>: 11: disconnected by user
# 	 ...
# 	 Received disconnect from <*>: 11: disconnected by user
#
# Cluster  38
# 2
# 	 warning: TLS library problem: error:140760FC:SSL routines:SSL23_GET_CLIENT_HELLO:unknown protocol:s23_srvr.c:649:
# 	 warning: TLS library problem: error:14076102:SSL routines:SSL23_GET_CLIENT_HELLO:unsupported protocol:s23_srvr.c:557:
# 	 ...
# 	 warning: TLS library problem: error:140760FC:SSL routines:SSL23_GET_CLIENT_HELLO:unknown protocol:s23_srvr.c:649:
# 	 warning: TLS library problem: error:14076102:SSL routines:SSL23_GET_CLIENT_HELLO:unsupported protocol:s23_srvr.c:557:
#
# Cluster  25
# 2
# 	 "POST /chat/post.php HTTP/1.1" 404 499 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "POST /chat/post.php HTTP/1.1" 404 500 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 ...
# 	 "POST /chat/post.php HTTP/1.1" 404 499 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
# 	 "POST /chat/post.php HTTP/1.1" 404 500 "about:blank" "Node.js (linux; U; rv:v4.9.1) AppleWebKit/537.36 (KHTML, like Gecko)"
#
# Cluster  32
# 1
# 	 New session 14 of user root.
# 	 ...
# 	 New session 14 of user root.
#
# Cluster  6
# 2
# 	 "CLUR / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET / HTTP/1.1" 200 34990 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "CLUR / HTTP/1.1" 501 496 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 "GET / HTTP/1.1" 200 34990 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  18
# 1
# 	 (root) CMD (  [ -x /usr/lib/php5/maxlifetime ] && [ -x /usr/lib/php5/sessionclean ] && [ -d /var/lib/php5 ] && /usr/lib/php5/sessionclean /var/lib/php5 $(/usr/lib/php5/maxlifetime))
# 	 ...
# 	 (root) CMD (  [ -x /usr/lib/php5/maxlifetime ] && [ -x /usr/lib/php5/sessionclean ] && [ -d /var/lib/php5 ] && /usr/lib/php5/sessionclean /var/lib/php5 $(/usr/lib/php5/maxlifetime))
#
# Cluster  47
# 1
# 	 Connection closed by <*> [preauth]
# 	 ...
# 	 Connection closed by <*> [preauth]
#
# Cluster  13
# 1
# 	 <*>: openFlag: Stage 1
# 	 ...
# 	 <*>: openFlag: Stage 1
#
# Cluster  31
# 1
# 	 "GET /elements.html HTTP/1.1" 200 6913 "-" "python-requests/2.16.0"
# 	 ...
# 	 "GET /elements.html HTTP/1.1" 200 6913 "-" "python-requests/2.16.0"
#
# Cluster  48
# 1
# 	 warning: TLS library problem: error:14094410:SSL routines:SSL3_READ_BYTES:sslv3 alert handshake failure:s3_pkt.c:1278:SSL alert number 40:
# 	 ...
# 	 warning: TLS library problem: error:14094410:SSL routines:SSL3_READ_BYTES:sslv3 alert handshake failure:s3_pkt.c:1278:SSL alert number 40:
#
# Cluster  16
# 1
# 	 warning: non-SMTP command from unknown[<*>]: {:?????????S????0???I
# 	 ...
# 	 warning: non-SMTP command from unknown[<*>]: {:?????????S????0???I
#
# Cluster  22
# 1
# 	 "GET /evox/about HTTP/1.1" 404 466 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
# 	 ...
# 	 "GET /evox/about HTTP/1.1" 404 466 "-" "Mozilla/5.0 (compatible; Nmap Scripting Engine; https://nmap.org/book/nse.html)"
#
# Cluster  43
# 1
# 	 Started Session 14 of user root.
# 	 ...
# 	 Started Session 14 of user root.
#
# 5

# %%
import random
random.seed(r_state)

center = [0]*len(clustered_sentences)
for i, cluster in clustered_sentences.items():
    center[i] = random.choice(cluster)

d = dict(zip(corpus, list(map(lambda i: center[i],cluster_assignment))))
d2 = dict(zip(corpus, cluster_assignment2))

df['EventTemplate'] = list(map(lambda s:d[s], content))
df['EventTemplate2'] = list(map(lambda s:d2[s], content))
df.to_csv(os.path.join(root_folder, "NLP_label_syslog.csv"), index=False)
